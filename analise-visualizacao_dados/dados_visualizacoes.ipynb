# %%
import pandas as pd
import numpy as np
import seaborn  as sns

# %%
df_rat = pd.read_csv('ratings.csv')
df_rat.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df_rat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
df_rat.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
df_rat.columns = 'usuarioId', 'filmeId', 'nota', 'momento'
df_rat
# Out:
#         usuarioId  filmeId  nota     momento
# 0               1        1   4.0   964982703
# 1               1        3   4.0   964981247
# 2               1        6   4.0   964982224
# 3               1       47   5.0   964983815
# 4               1       50   5.0   964982931
# ...           ...      ...   ...         ...
# 100831        610   166534   4.0  1493848402
# 100832        610   168248   5.0  1493850091
# 100833        610   168250   5.0  1494273047
# 100834        610   168252   5.0  1493846352
# 100835        610   170875   3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
df_rat['usuarioId'].nunique()
# Out:
# 610

# %%
df_rat['nota'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
df_rat['nota'].value_counts()
# Out:
# nota
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
df_rat['nota'].mean()
# Out:
# np.float64(3.501556983616962)

# %%
df_rat['nota'].plot()
# Out:
# <Axes: >

# %%
df_rat['nota'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_rat['nota'].median()
# Out:
# 3.5

# %%
df_rat['nota'].describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
sns.boxplot(df_rat['nota'])
# Out:
# <Axes: ylabel='nota'>

# %% [markdown]
# ###Nessa aula, você aprendeu a:
#
# *    Importar pandas (biblioteca de análise de dados)
# *    Ler dados CSV;
# *    Fazer upload de arquivo para o Google Colab;
# *    Renomear colunas;
# *    Contar dados;
# *    Melhorar a visualização das informações.
